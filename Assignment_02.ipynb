# %% [markdown]
# <a href="https://colab.research.google.com/github/baanujan-18/Statistical-Learning-e20030/blob/main/Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Assignment 2

# %% [markdown]
# ---

# %% [markdown]
# # Q3 )Transformer Failiures

# %% [markdown]
#  **(1)**
#
#  1 .
#
# The Sample space set of all the possible outcomesIn this case problem state number of Failure can be **X**  So Ω shold be like
#
#
#  $$ Ω = \left\{ 0,1,2,3 \right\} $$
#
#  2 .
#
#  The σ -  algebra is the collection of the all the measureable events
#
#  $$ ℱ = \left\{∅ , \left\{ 0\right\},\left\{ 1\right\},\left\{ 2\right\},\left\{ 3\right\},\left\{ 0,1\right\},\left\{ 0,2\right\},.....\left\{ 0,1,2,3\right\}\right\}$$
#
#  since Ω has 4 element so ℱ has  2^4 elements means ℱ has total 16 elements
#
#  3 .
#
#  Probability measure **P** is a function that map every event in Our σ -algebra ℱ to the real number  0  and 1
#
#  $$P : ℱ → [0,1 ]$$
#
#  in this 3 rd question they given each weight
#
#  |Value of X| Value of P(X) |
#  |----------|---------------|
#  |   0      |   0.5         |
#  |    1     |   0.3         |
#  |    2     | 0.15          |
#  |  3       | 0.05          |
#  | **∑P(x)    = 1**|

# %% [markdown]
# ---

# %% [markdown]
# **(2)**
#
# Define **X** as a random variable on this space.
#
# To define $X$ as a random variable on the space $(\Omega, \mathcal{F}, P)$, we define it as a function $X: \Omega \rightarrow \mathbb{R}$ such that for every outcome $\omega \in \Omega$:
#
# $$X(\omega) = \omega$$
#
#
# Explicitly, this mapping is:
#
# * $X(0) = 0$
# * $X(1) = 1$
# * $X(2) = 2$
# * $X(3) = 3$

# %% [markdown]
# ---

# %% [markdown]
# **(3)**
#
# Probability mass funtion of **X**:
#
# $$P(X=x) = \begin{cases} 0.50, & x=0 \\ 0.30, & x=1 \\ 0.15, & x=2 \\ 0.05, & x=3 \\ 0, & \text{otherwise} \end{cases}$$
#
# $$\sum_{x=0}^{3} P(X=x) = 0.50 + 0.30 + 0.15 + 0.05  = 1. 00$$
#
# So via summation check we are able to varify This pdf mathamatically valied

# %% [markdown]
# ---

# %% [markdown]
# **(4)**
#
# Compute the  expectation  value 𝔼[**X**] .
#
#
# | x  |P(X)|x.P(x)|
# |----|----|------|
# |0|0.50|0|
# |1|0.30|0.30|
# |2|0.15|0.30|
# |3|0.05|0.15|
#
#
# $$E[X] = ∑x.P(X)$$
#
# $$E[X]= 0+0.30+0.30+0.15$$
#
#
# > $$E[X] = 0.75$$

# %% [markdown]
# ---

# %% [markdown]
# **(5)**
#
# Compute the  varience **Var[x]**:
#
# |x|P(x)|x^2.P(x)|
# |---|---|---|
# |0|0.50|0|
# |1|0.30|0.30|
# |2|0.15|0.60|
# |3|0.05|0.45|
#
# > $$E[X^2] = 0 + 0.30 + 0.60 + 0.45 $$
# > $$E[X^2] =1.35 $$
#
# $$Var[X] = E[X^2] - (E[X])^2 $$
# $$Var[X] = 1.35 - (0.75)^2$$
#
#
#
# > $$Var[X] = 0.7875$$

# %% [markdown]
# ---

# %% [markdown]
# **(6)**
#
# Find P(X≥1) and P(X≥2)
#
#
# > $$P(X ≥ 1) = P(X = 1) + P(X = 2) + P( X = 3)$$
# $$P(X ≥ 1 ) = 0.30 + 0.15 +0.05$$
# >$$P(X ≥ 1) = 0.5 $$
#
#
# > $$P(X ≥ 2) = P(X = 2) + P( X = 3)$$
# $$P(X ≥ 2 ) = 0.15 +0.05$$
# >$$P(X ≥ 2) = 0.2 $$

# %% [markdown]
# **(7)**
#
# Briefly explain the practical meaning of the expectation and variance in this setting.
#
#
# The Expectation of 0.75 serves as the "steady-state" baseline for the electricity district’s long-term planning. While no single day will ever result in exactly 0.75 failures, this figure represents the average demand on maintenance services over many months. For a manager, this suggests that the system typically experiences less than one emergency per day, allowing them to calculate the total volume of spare parts, fuel for service vehicles, and annual labor costs needed to keep the grid operational. It effectively converts the randomness of daily reports into a stable figure used for financial budgeting and general resource allocation.
#
# The Variance of 0.7875 provides a critical measure of the system's volatility and the inherent risk of the grid's failure patterns. A high variance indicates that while "quiet days" with zero failures are frequent, the district must still account for the "spikiness" of the data—those rare but high-impact days where three transformers fail simultaneously. Practically, this value dictates the size of the emergency response team; the district cannot staff based on the average alone because the variance tells them that the workload will often swing significantly above that average. It essentially measures how much "buffer room" or emergency standby capacity is required to handle unpredictable surges in equipment failure

# %%
import numpy as np

# Define the Random Variable values and their probabilities
x_values = np.array([0, 1, 2, 3])
probabilities = np.array([0.50, 0.30, 0.15, 0.05])

# 4. Compute Expectation E[X]
expectation = np.sum(x_values * probabilities)

# 5. Compute Variance Var(X)
# Formula: E[X^2] - (E[X])^2
expectation_x_squared = np.sum((x_values**2) * probabilities)
variance = expectation_x_squared - (expectation**2)

print(f"Expectation E[X]: {expectation}")
print(f"Variance Var(X): {variance}")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
bars = plt.bar(x_values, probabilities, color='skyblue', edgecolor='navy', alpha=0.7)

# Adding labels and titles
plt.title('Probability Mass Function (PMF) of Transformer Failures', fontsize=14)
plt.xlabel('Number of Failures (X)', fontsize=12)
plt.ylabel('Probability P(X=x)', fontsize=12)
plt.xticks(x_values)
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Add probability labels on top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, f'{yval:.2f}', ha='center', va='bottom')

# Highlight the Expectation (Mean)
plt.axvline(expectation, color='red', linestyle='dashed', linewidth=2, label=f'Mean (E[X] = {expectation})')
plt.legend()

plt.show()

# %%
# Cumulative probabilities for question 6
p_ge_1 = np.sum(probabilities[x_values >= 1])
p_ge_2 = np.sum(probabilities[x_values >= 2])

print(f"P(X >= 1): {p_ge_1}")
print(f"P(X >= 2): {p_ge_2}")

# Plotting the Cumulative Distribution Function (CDF)
cdf = np.cumsum(probabilities)

plt.figure(figsize=(8, 5))
plt.step(x_values, cdf, where='post', color='darkorange', linewidth=2.5)
plt.title('Cumulative Distribution Function (CDF)', fontsize=14)
plt.xlabel('Number of Failures (x)', fontsize=12)
plt.ylabel('P(X <= x)', fontsize=12)
plt.xticks(x_values)
plt.grid(True, alpha=0.3)
plt.fill_between(x_values, cdf, step="post", alpha=0.2, color='orange')
plt.show()

# %% [markdown]
# ----
# ---

# %% [markdown]
# # Q(4)
#
# 1 .  Construct  a Probability  space (Ω,ℱ,P) Suitable for this model.
#
#
# given distribution is a Beta distribution
#
#
# $$f(x) = \begin{cases} \frac{x^1(1-x)^{17}}{B(2,18)}, & 0 < x < 1 \\ 0, & \text{otherwise} \end{cases}$$
#
# So the Sample space :$$Ω = {[0,1]}$$
#
# Then the σ - Algebra is :$$\mathcal{F} = \mathcal{B}([0, 1])$$
#
#
# Probability Measure : $$P(A) = \int_{A} f(x) \, dx$$
#
# $$P(A) = \int_{A} \frac{x(1-x)^{17}}{B(2, 18)} \, dx \quad \forall A \in \mathcal{F}$$

# %% [markdown]
# ---

# %% [markdown]
# 2. Define **X** as a continuous random variable on this space.
#
#
#
# $$X: \Omega \to \mathbb{R}$$
#
# Specifically, we define $X$ as the identity mapping, where for every outcome $\omega$ in our sample space $\Omega = [0, 1]$, the random variable takes that exact value:$$X(\omega) = \omega$$

# %% [markdown]
# ---

# %% [markdown]
# Write down the probability density function of **X**
#
#
#
# $$f(x) = \begin{cases} \frac{x^1(1-x)^{17}}{B(2,18)}, & 0 < x < 1 \\ 0, & \text{otherwise} \end{cases}$$

# %% [markdown]
# ---

# %% [markdown]
# 3. Verify that **f** is a valid probability density function.
#
#
# $$I =\int_{0}^{1} \left( \frac{x(1-x)^{17}}{B(2, 18)} \right) \, dx $$
#
# $$I = \frac{1}{B(2, 18)} \int_{0}^{1} x^{2-1}(1-x)^{18-1} \, dx$$
#
#
# The integral part $\int_{0}^{1} x^{2-1}(1-x)^{18-1} \, dx$ is, by definition, $B(2, 18)$. Substituting the Gamma identities for both the numerator and
#
# denominator:$$I = \frac{1}{\left( \frac{\Gamma(2)\Gamma(18)}{\Gamma(20)} \right)} \cdot \left( \frac{\Gamma(2)\Gamma(18)}{\Gamma(20)} \right)$$
#
#
#
#
# $$\Gamma(2) = 1! = 1$$
# $$\Gamma(18) = 17!$$
# $$\Gamma(20) = 19!$$
#
# Substituting these into the identity:$$B(2, 18) = \frac{1 \cdot 17!}{19!} = \frac{17!}{19 \cdot 18 \cdot 17!} = \frac{1}{342}$$Now, returning to the full expression:$$I = \frac{\int_{0}^{1} x(1-x)^{17} \, dx}{1/342}$$$$I = \frac{1/342}{1/342}$$
#
# $$I = 1 $$
#
#
#  $\int_{0}^{1} f(x) \, dx = 1$ and $f(x) \geq 0$ for all $x$, $f(x)$ is a valid probability density function.

# %% [markdown]
# ----

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# Define the shape parameters based on your derivation
alpha = 2
beta_val = 18

# Generate 500 points between 0 and 1 for a smooth curve
x = np.linspace(0, 1, 500)

# Calculate the probability density function (PDF)
y = beta.pdf(x, alpha, beta_val)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, label=f'Beta({alpha}, {beta_val})', color='#2E86C1', lw=2.5)

# Formatting the graph
plt.title(r'Probability Density Function: $f(x) = \frac{x(1-x)^{17}}{B(2, 18)}$', fontsize=14)
plt.xlabel('$x$', fontsize=12)
plt.ylabel('$f(x)$', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.axhline(0, color='black', lw=1)
plt.axvline(0, color='black', lw=1)

# Highlight the mean (E[X] = 0.1)
plt.axvline(0.1, color='red', linestyle=':', label='Mean (0.1)')

plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #5 Compute the expectation **E[X]**.
#
#
# $$ E[X] = \int_{-∞}^{+∞}x.f(x) dx$$
#
# for Beta distribution we alredy derive $$E[X] = \frac{\alpha}{\alpha + \beta}$$
#
# in this case we  already Known :$$ α = 2 ,β =18$$; So
#
# $$E[X] = \frac{2}{2 + 18}$$
# $$E[X] = \frac{2}{20}$$
# $$E[X] = \frac{1}{10}$$
#
#
# $$E[X] = 0.1$$

# %% [markdown]
# ---

# %% [markdown]
# #6.Compute the variance Var(X).
#
# $$Var(X) = \int_{-∞}^{+∞}x^2.f(x) dx - (\int_{-∞}^{+∞}x.f(x) dx)^2$$
#
# $$Var(x) = E(X^2) - (E(X))^2$$
#
#
# for Beta ditribution We already derive
#
# $$Var(X) = \frac{\alpha \beta}{(\alpha + \beta)^2 (\alpha + \beta + 1)}$$
#
# $$Var(X) = (2*18)/((2+18)^2(2+18+1))$$
#
# $$Var(X) = \frac{36}{8400}$$
#
# $$Var(X) \approx 0.004286$$

# %% [markdown]
# ---

# %% [markdown]
# #7 Find the probability that the defective proportion is at most  0.1 that is, compute
#
# $$P(X \le 0.10) = \int_{0}^{0.10} \frac{x(1-x)^{17}}{B(2, 18)} \, dx$$
#
# $$P(X \le 0.10) = 342 \int_{0}^{0.10} x(1-x)^{17} \, dx$$
#
# $$P(X \le 0.10) = 1 - 2.8(0.9)^{18}$$
#
# $$P(X \le 0.10) \approx 1 - 0.4203$$
#
# $$P(X \le 0.10) \approx 0.5797$$

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Q5) Expected Project Completion Time
# **Parameters:**
# * Minimum ($a$) = 4
# * Maximum ($b$) = 10
# * Mode ($c$) = 6

# %% [markdown]
# ### 1. Support of $X$
# The support is the interval of all possible values:
# **Support:** $[4, 10]$
#
# ### 2. Probability Density Function $f_X(x)$
# Using the triangular distribution formula:
# $$f_X(x) = \begin{cases}
# \frac{x-4}{6} & \text{for } 4 \le x < 6 \\
# \frac{10-x}{12} & \text{for } 6 \le x \le 10 \\
# 0 & \text{otherwise}
# \end{cases}$$
#
# ### 3. Verification
# Area of triangle = $\frac{1}{2} \times \text{base} \times \text{height}$
# * Base = $10 - 4 = 6$
# * Height = $f_X(6) = \frac{6-4}{6} = \frac{1}{3}$
# * Area = $\frac{1}{2} \times 6 \times \frac{1}{3} = 1$

# %%
# 4. Compute Expectation E[X]
a, b, c = 4, 10, 6
expectation = (a + b + c) / 3
print(f"Expectation E[X]: {expectation:.2f} hours")

# 5. Compute Variance Var(X)
variance = (a**2 + b**2 + c**2 - a*b - a*c - b*c) / 18
print(f"Variance Var(X): {variance:.2f} hours^2")

# %% [markdown]
# ### 6. Interpretation
# * **a (4):** The optimistic (shortest) time.
# * **b (10):** The pessimistic (longest) time.
# * **c (6):** The most likely time.
#
# ### 7. Model Reasoning
# The Triangular distribution is ideal for project management when historical data is limited, as it only requires three expert-judged estimates to model uncertainty.

# %% [markdown]
# ### 8. Compute $P(X \le 5)$
# Since $5$ is in the first interval $[4, 6)$:
# $$P(X \le 5) = \int_{4}^{5} \frac{x-4}{6} dx = \left[ \frac{(x-4)^2}{12} \right]_{4}^{5} = \frac{1}{12} \approx 0.0833$$
#
# ### 9. Compute $P(5 \le X \le 8)$
# $$P(5 \le X \le 8) = 1 - P(X < 5) - P(X > 8)$$
# * $P(X < 5) = 1/12$
# * $P(X > 8) = \int_{8}^{10} \frac{10-x}{12} dx = \frac{4}{24} = 2/12$
# * $P(5 \le X \le 8) = 1 - 3/12 = 0.75$

# %% [markdown]
# ### 10. Project Planning Usage
# Used in **PERT** and **Monte Carlo simulations** to assess the risk of delays and identify critical path sensitivities.

# %% [markdown]
# ---

# %% [markdown]
# # Q6) Expected Project Completion Time Using PERT
# **Parameters:**
# * Shortest time ($a$) = 8 days
# * Longest time ($b$) = 20 days
# * Most likely time ($c$) = 11 days

# %%
# 1. Compute Shape Parameters alpha and beta
a, b, c = 8, 20, 11

alpha = 1 + 4 * ((c - a) / (b - a))
beta = 1 + 4 * ((b - c) / (b - a))

print(f"Shape Parameter alpha: {alpha}")
print(f"Shape Parameter beta: {beta}")

# %% [markdown]
# ### 2. Support of $X$
# The support is the interval of possible durations:
# **Support:** $[8, 20]$
#
# ### 3. Probability Density Function $f_X(x)$
# Substituting $\alpha=2, \beta=4, a=8, b=20$:
# $$f_X(x) = \frac{(x-8)(20-x)^3}{B(2, 4) \cdot 12^5}, \quad 8 \le x \le 20$$
#
# ### 4. Probability Space $(\Omega, \mathfrak{F}, P)$
# * **$\Omega$:** $[8, 20]$
# * **$\mathfrak{F}$:** Borel $\sigma$-algebra $\mathcal{B}([8, 20])$
# * **$P$:** Measure defined by the PDF $f_X(x)$
#
# ### 5. Random Variable $X$
# $X$ is defined as the identity mapping $X(\omega) = \omega$, representing the number of days to complete the task.

# %% [markdown]
# ### 2. Support of $X$
# The support is the interval of possible durations:
# **Support:** $[8, 20]$
#
# ### 3. Probability Density Function $f_X(x)$
# Substituting $\alpha=2, \beta=4, a=8, b=20$:
# $$f_X(x) = \frac{(x-8)(20-x)^3}{B(2, 4) \cdot 12^5}, \quad 8 \le x \le 20$$
#
# ### 4. Probability Space $(\Omega, \mathfrak{F}, P)$
# * **$\Omega$:** $[8, 20]$
# * **$\mathfrak{F}$:** Borel $\sigma$-algebra $\mathcal{B}([8, 20])$
# * **$P$:** Measure defined by the PDF $f_X(x)$
#
# ### 5. Random Variable $X$
# $X$ is defined as the identity mapping $X(\omega) = \omega$, representing the number of days to complete the task.

# %%
import math

# 6. Expectation E[X]
expectation_pert = (a + 4*c + b) / 6
print(f"Expected Completion Time E[X]: {expectation_pert} days")

# 7. Variance Var(X)
variance_pert = ((expectation_pert - a) * (b - expectation_pert)) / 7
print(f"Approximate Variance Var(X): {variance_pert:.2f} days^2")

# 8. Standard Deviation sigma
std_dev = math.sqrt(variance_pert)
print(f"Standard Deviation sigma: {std_dev:.2f} days")

# %% [markdown]
# ### 9. PERT vs. Triangular Distribution
# The **PERT distribution** is more appropriate here because it follows a smooth, bell-like curve. Unlike the Triangular distribution, which has a sharp peak and linear slopes, PERT emphasizes the most likely values and gives less weight to the extreme "Best/Worst" case scenarios. This typically results in a more realistic estimation of human-timed tasks.
#
#
#
# ### 10. Practical Meaning
# * **$a, b, c$:** Represent the optimistic, pessimistic, and most likely durations.
# * **$E[X]$:** The balanced estimate used for project scheduling.
# * **$\sigma$:** Measures the uncertainty; a larger $\sigma$ indicates a higher risk that the project will deviate from the expected 12 days.

# %% [markdown]
# ---

# %% [markdown]
# # Q7) If the PERT Expectation is to Match Our Intuition
# **Given:**
# * $a = 5$
# * $c = 11$
# * $E[X] = c = 11$
#
# ### 1. Find $b$
# Using $E[X] = \frac{a + 4c + b}{6}$:
# $$11 = \frac{5 + 4(11) + b}{6}$$
# $$66 = 49 + b \implies b = 17$$
#
# ### 2. Variance Analysis
# When $E[X] = c$, the distribution is symmetric.

# %%
a = 5
c = 11
e_x = 11
b = 6 * e_x - a - 4*c

variance = ((e_x - a) * (b - e_x)) / 7

print(f"Maximum time b: {b} days")
print(f"Variance: {variance:.2f}")
